# %%
# Basic Level (Questions 1-150)
# Descriptive & Basic Queries (Questions 1-50)
# Question 1: Find total number of orders in the dataset.

# Question 2: Find the earliest order date.

# Question 3: Find the latest order date.

# Question 4: Find the total number of unique customers.

# Question 5: Find the total number of unique products sold.

# Question 6: Find the total number of unique categories.

# Question 7: Find the total number of unique sub-categories.

# Question 8: Count number of orders in each region.

# Question 9: Count number of orders by state.

# Question 10: Count number of orders by city.

# Question 11: Find the most common ship mode.

# Question 12: Find the least common ship mode.

# Question 13: Count number of orders shipped with "Same Day" mode.

# Question 14: Count number of orders shipped with "First Class".

# Question 15: Count number of orders shipped with "Second Class".

# Question 16: Count number of orders shipped with "Standard Class".

# Question 17: Find number of orders in each year.

# Question 18: Find number of orders in each quarter.

# Question 19: Find number of orders in each month.

# Question 20: Find number of orders in each weekday.

# Question 21: Count orders with discount applied.

# Question 22: Count orders without discount.

# Question 23: Count orders where discount = 0.

# Question 24: Count orders where discount > 0.2.

# Question 25: Count orders where discount = 0.5.

# Question 26: Find maximum discount given.

# Question 27: Find minimum discount given.

# Question 28: Count orders where profit < 0.

# Question 29: Count orders where profit = 0.

# Question 30: Count orders where profit > 100.

# Question 31: Count orders where sales > 1000.

# Question 32: Find total quantity sold.

# Question 33: Find average quantity per order.

# Question 34: Find average sales per order.

# Question 35: Find average profit per order.

# Question 36: Find maximum sales in a single order.

# Question 37: Find minimum sales in a single order.

# Question 38: Find maximum profit in a single order.

# Question 39: Find minimum profit in a single order.

# Question 40: Find number of orders per customer.

# Question 41: Find customers who placed only 1 order.

# Question 42: Find customers who placed more than 10 orders.

# Question 43: Find total number of states represented.

# Question 44: Find total number of cities represented.

# Question 45: Find number of orders placed from California.

# Question 46: Find number of orders placed from New York.

# Question 47: Find number of orders placed from Texas.

# Question 48: Find number of orders placed from Florida.

# Question 49: Find number of orders shipped after 5 days of order.

# Question 50: Find average shipping time in days.

# Sales & Profit Analysis (Questions 51-100)
# Question 51: Find total sales.

# Question 52: Find total profit.

# Question 53: Find average sales per order.

# Question 54: Find average profit per order.

# Question 55: Find sales by category.

# Question 56: Find profit by category.

# Question 57: Find sales by sub-category.

# Question 58: Find profit by sub-category.

# Question 59: Find highest sales category.

# Question 60: Find highest profit category.

# Question 61: Find lowest profit category.

# Question 62: Find lowest sales sub-category.

# Question 63: Find highest profit sub-category.

# Question 64: Find lowest profit sub-category.

# Question 65: Find top 10 profitable products.

# Question 66: Find top 10 least profitable products.

# Question 67: Find top 10 best-selling products by sales.

# Question 68: Find top 10 best-selling products by quantity.

# Question 69: Find bottom 10 products by sales.

# Question 70: Find bottom 10 products by profit.

# Question 71: Find total sales by year.

# Question 72: Find total profit by year.

# Question 73: Find sales growth year by year.

# Question 74: Find profit growth year by year.

# Question 75: Find sales by quarter.

# Question 76: Find profit by quarter.

# Question 77: Find sales by month.

# Question 78: Find profit by month.

# Question 79: Find month with highest sales.

# Question 80: Find month with highest profit.

# Question 81: Find month with lowest sales.

# Question 82: Find month with lowest profit.

# Question 83: Find total sales by weekday.

# Question 84: Find total profit by weekday.

# Question 85: Find weekday with highest sales.

# Question 86: Find weekday with lowest sales.

# Question 87: Find weekday with highest profit.

# Question 88: Find weekday with lowest profit.

# Question 89: Find state with highest sales.

# Question 90: Find state with highest profit.

# Question 91: Find state with lowest sales.

# Question 92: Find state with lowest profit.

# Question 93: Find region with highest sales.

# Question 94: Find region with highest profit.

# Question 95: Find region with lowest sales.

# Question 96: Find region with lowest profit.

# Question 97: Find average discount overall.

# Question 98: Find average discount in each category.

# Question 99: Find average discount in each sub-category.

# Question 100: Compare total sales vs profit across regions.

# Customer & Segment Analysis (Questions 101-150)
# Question 101: Count customers in each region.

# Question 102: Count customers in each state.

# Question 103: Count customers in each city.

# Question 104: Find total sales by customer.

# Question 105: Find total profit by customer.

# Question 106: Find average sales per customer.

# Question 107: Find average profit per customer.

# Question 108: Find customer with highest sales.

# Question 109: Find customer with highest profit.

# Question 110: Find customer with lowest sales.

# Question 111: Find customer with lowest profit.

# Question 112: Find customers with negative profit.

# Question 113: Find customers with > 10 orders.

# Question 114: Find customers with < 2 orders.

# Question 115: Find repeat customers across multiple years.

# Question 116: Find customers who ordered only once.

# Question 117: Count customers by segment.

# Question 118: Find sales by segment.

# Question 119: Find profit by segment.

# Question 120: Find most profitable segment.

# Question 121: Find least profitable segment.

# Question 122: Find most sales-generating segment.

# Question 123: Find least sales-generating segment.

# Question 124: Find segment with highest average discount.

# Question 125: Find segment with lowest average discount.

# Question 126: Find top 5 customers by sales in each segment.

# Question 127: Find top 5 customers by profit in each segment.

# Question 128: Find top 5 loss-making customers.

# Question 129: Find customers with largest order value.

# Question 130: Find customers with smallest order value.

# Question 131: Find number of unique customers each year.

# Question 132: Find retention rate year over year.

# Question 133: Find churned customers (present last year, not this year).

# Question 134: Find new customers (present this year, not last year).

# Question 135: Find sales contribution of top 10 customers.

# Question 136: Find profit contribution of top 10 customers.

# Question 137: Find customers who purchased from all categories.

# Question 138: Find customers who purchased only furniture.

# Question 139: Find customers who purchased only technology.

# Question 140: Find customers who purchased only office supplies.

# Question 141: Find average order size per segment.

# Question 142: Find average discount per segment.

# Question 143: Find segment with maximum number of customers.

# Question 144: Find segment with minimum number of customers.

# Question 145: Find customer with maximum quantity purchased.

# Question 146: Find customer with minimum quantity purchased.

# Question 147: Find customer who bought most different products.

# Question 148: Find customer who bought most categories.

# Question 149: Find customer who bought most sub-categories.

# Question 150: Find customer who bought across most states.

# Intermediate Level (Questions 151-350)
# Product & Category Analysis (Questions 151-200)
# Question 151: Count number of products per category.

# Question 152: Count number of products per sub-category.

# Question 153: Find most sold product by sales.

# Question 154: Find most sold product by profit.

# Question 155: Find most sold product by quantity.

# Question 156: Find least sold product by sales.

# Question 157: Find least sold product by profit.

# Question 158: Find least sold product by quantity.

# Question 159: Find average sales per product.

# Question 160: Find average profit per product.

# Question 161: Find products with sales > 5000.

# Question 162: Find products with profit > 1000.

# Question 163: Find products with negative profit.

# Question 164: Find products with discount > 0.5.

# Question 165: Find products with no discount.

# Question 166: Find top 10 profitable products per category.

# Question 167: Find top 10 loss-making products per category.

# Question 168: Find sub-category with highest sales.

# Question 169: Find sub-category with lowest sales.

# Question 170: Find sub-category with highest profit.

# Question 171: Find sub-category with lowest profit.

# Question 172: Find sub-category with maximum discount.

# Question 173: Find sub-category with minimum discount.

# Question 174: Compare sales across categories.

# Question 175: Compare profit across categories.

# Question 176: Compare average discount across categories.

# Question 177: Compare quantity sold across categories.

# Question 178: Find correlation between sales and profit per product.

# Question 179: Find correlation between discount and profit per product.

# Question 180: Find top 5 profitable sub-categories in each region.

# Question 181: Find top 5 profitable products in each state.

# Question 182: Find most profitable category in each region.

# Question 183: Find most profitable sub-category in each state.

# Question 184: Find average profit margin per category.

# Question 185: Find average profit margin per sub-category.

# Question 186: Find product with maximum profit margin.

# Question 187: Find product with minimum profit margin.

# Question 188: Find product with highest sales but negative profit.

# Question 189: Find product with highest discount but positive profit.

# Question 190: Find product sold in maximum number of states.

# Question 191: Find product sold in minimum number of states.

# Question 192: Find product sold in maximum number of regions.

# Question 193: Find product sold in minimum number of regions.

# Question 194: Find category with maximum contribution to total sales.

# Question 195: Find category with maximum contribution to total profit.

# Question 196: Find category with minimum contribution to sales.

# Question 197: Find category with minimum contribution to profit.

# Question 198: Rank categories by average sales per product.

# Question 199: Rank sub-categories by average profit per product.

# Question 200: Rank products by average discount.

# Time Series & Trend Analysis (Questions 201-250)
# Question 201: Find monthly sales trend for each year.

# Question 202: Find monthly profit trend for each year.

# Question 203: Find year with highest sales.

# Question 204: Find year with lowest sales.

# Question 205: Find year with highest profit.

# Question 206: Find year with lowest profit.

# Question 207: Find quarterly sales trend.

# Question 208: Find quarterly profit trend.

# Question 209: Find moving average of sales (3 months).

# Question 210: Find moving average of profit (3 months).

# Question 211: Find moving average of sales (6 months).

# Question 212: Find moving average of profit (6 months).

# Question 213: Compare year-over-year growth in sales.

# Question 214: Compare year-over-year growth in profit.

# Question 215: Compare month-over-month growth in sales.

# Question 216: Compare month-over-month growth in profit.

# Question 217: Find seasonal peak months in sales.

# Question 218: Find seasonal low months in sales.

# Question 219: Find holiday season sales (Nov–Dec).

# Question 220: Find holiday season profit (Nov–Dec).

# Question 221: Compare sales between weekdays and weekends.

# Question 222: Compare profit between weekdays and weekends.

# Question 223: Compare sales before and after discount campaigns.

# Question 224: Compare profit before and after discount campaigns.

# Question 225: Compare sales during Q4 vs Q1.

# Question 226: Compare profit during Q4 vs Q1.

# Question 227: Find sales growth in each region per year.

# Question 228: Find profit growth in each region per year.

# Question 229: Find sales trend in furniture category.

# Question 230: Find profit trend in technology category.

# Question 231: Find sales trend in office supplies category.

# Question 232: Find profit trend in furniture category.

# Question 233: Find sales growth by segment year over year.

# Question 234: Find profit growth by segment year over year.

# Question 235: Find number of orders month by month.

# Question 236: Find number of orders quarter by quarter.

# Question 237: Find sales during Black Friday week.

# Question 238: Find profit during Black Friday week.

# Question 239: Find sales spike in December.

# Question 240: Find sales dip in January.

# Question 241: Find month with highest discount usage.

# Question 242: Find month with lowest discount usage.

# Question 243: Find region with fastest growing sales trend.

# Question 244: Find region with fastest growing profit trend.

# Question 245: Compare sales in first half vs second half of year.

# Question 246: Compare profit in first half vs second half of year.

# Question 247: Find year with maximum orders placed.

# Question 248: Find year with minimum orders placed.

# Question 249: Compare monthly orders in California vs New York.

# Question 250: Compare yearly profit in East vs West region.

# Advanced / Mixed / Case-based Questions (Questions 251-350)
# Question 251: Find top 10 customers contributing most to profit.

# Question 252: Find top 10 customers contributing most to sales.

# Question 253: Find bottom 10 customers in profit.

# Question 254: Find bottom 10 customers in sales.

# Question 255: Find customers with sales > 5000 but profit < 0.

# Question 256: Find customers with highest discounts used.

# Question 257: Find customers who always order "Same Day" delivery.

# Question 258: Find products causing maximum losses.

# Question 259: Find products with consistently high profits across years.

# Question 260: Find customers with negative profit orders in multiple years.

# Question 261: Find states where sales growing but profit declining.

# Question 262: Find sub-categories where discount reduces profit drastically.

# Question 263: Find orders shipped more than 10 days after order date.

# Question 264: Find orders shipped within 1 day.

# Question 265: Compare shipping time across ship modes.

# Question 266: Compare profit across shipping modes.

# Question 267: Compare sales per order across shipping modes.

# Question 268: Find which region has highest average order value.

# Question 269: Find which region has lowest average order value.

# Question 270: Find cities with highest total profit.

# Question 271: Find cities with negative total profit.

# Question 272: Find customers who buy only high-discounted products.

# Question 273: Find customers who never received a discount.

# Question 274: Find states where furniture sales dominate.

# Question 275: Find states where technology sales dominate.

# Question 276: Find correlation between quantity and profit.

# Question 277: Find correlation between discount and sales.

# Question 278: Find correlation between discount and profit.

# Question 279: Find which category is most price-sensitive.

# Question 280: Find most profitable product per state.

# Question 281: Find loss-making product per state.

# Question 282: Find top-selling product per city.

# Question 283: Find top-profitable product per city.

# Question 284: Find total revenue contribution of top 20% products (Pareto).

# Question 285: Find profit contribution of top 20% customers (Pareto).

# Question 286: Apply ABC analysis on products by sales.

# Question 287: Apply ABC analysis on products by profit.

# Question 288: Apply RFM (Recency, Frequency, Monetary) analysis for customers.

# Question 289: Find repeat purchase rate across customers.

# Question 290: Find category with maximum repeat orders.

# Question 291: Find customer who ordered most frequently.

# Question 292: Find customer who spent maximum per order.

# Question 293: Find customer who spent minimum per order.

# Question 294: Find average shipping delay per state.

# Question 295: Find region with maximum shipping delay.

# Question 296: Find impact of shipping delay on profit.

# Question 297: Find sales during COVID years (2020–2021).

# Question 298: Find profit dip during COVID years (2020–2021).

# Question 299: Compare pre-COVID vs post-COVID sales.

# Question 300: Compare pre-COVID vs post-COVID profit.

# Question 301: Calculate profit ratio = profit ÷ sales for each order.

# Question 302: Find average profit ratio across all orders.

# Question 303: Rank categories by profit margin.

# Question 304: Rank sub-categories by profit margin.

# Question 305: Find top 3 categories with highest sales in each region.

# Question 306: Find top 3 categories with highest profit in each region.

# Question 307: Compare sales and profit share of East vs West.

# Question 308: Compare sales and profit share of Central vs South.

# Question 309: Find correlation between discount and quantity.

# Question 310: Find correlation between discount and sales.

# Question 311: Find correlation between discount and profit.

# Question 312: Compare average order value (AOV) by region.

# Question 313: Compare AOV by segment.

# Question 314: Find state with highest average discount.

# Question 315: Find state with lowest average discount.

# Question 316: Find top 5 states contributing most to profit.

# Question 317: Find top 5 states contributing most to loss.

# Question 318: Compare sales and profit trend before and after discount applied.

# Question 319: Compare sales and profit of orders with and without discount.

# Question 320: Find impact of discount levels (0–0.2, 0.2–0.4, 0.4–0.6, >0.6) on profit.

# Question 321: Find average sales per order for each ship mode.

# Question 322: Find average profit per order for each ship mode.

# Question 323: Find sales variance between ship modes.

# Question 324: Find profit variance between ship modes.

# Question 325: Find top 10 orders by sales amount.

# Question 326: Find top 10 orders by profit.

# Question 327: Find bottom 10 orders by profit.

# Question 328: Find bottom 10 orders by sales.

# Question 329: Compare category sales over years.

# Question 330: Compare category profit over years.

# Question 331: Find category with most volatile profit trend.

# Question 332: Find sub-category with most volatile sales trend.

# Question 333: Calculate CAGR (Compound Annual Growth Rate) of sales.

# Question 334: Calculate CAGR of profit.

# Question 335: Find year with maximum profit margin.

# Question 336: Find year with minimum profit margin.

# Question 337: Find month with maximum loss.

# Question 338: Find state with continuous profit growth.

# Question 339: Find state with continuous profit decline.

# Question 340: Compare sales-to-profit ratio for top 5 products.

# Question 341: Compare sales-to-profit ratio for bottom 5 products.

# Question 342: Find which states rely on discounts to drive sales.

# Question 343: Find which states maintain profit despite high discounts.

# Question 344: Identify "loss leaders" (products with high sales but negative profit).

# Question 345: Identify "star products" (high sales, high profit).

# Question 346: Identify "niche products" (low sales, high profit).

# Question 347: Customer Analysis (201–250)

# Question 348: Find customer lifetime value (CLV) = total sales per customer.

# Question 349: Rank customers by CLV.

# Question 350: Find customer lifetime profit.

# Advanced Level (Questions 351-500)
# Customer Analysis (Questions 351-400)
# Question 351: Rank customers by profit contribution.

# Question 352: Segment customers by sales: High (>10,000), Medium (1,000–10,000), Low (<1,000).

# Question 353: Segment customers by profit: High, Medium, Low.

# Question 354: Find repeat purchase rate per year.

# Question 355: Find top 5 customers in each region.

# Question 356: Find top 5 customers in each state.

# Question 357: Find most loyal customer (highest number of orders).

# Question 358: Find least loyal customer (only 1 order).

# Question 359: Find customer with largest single order.

# Question 360: Find customer with smallest single order.

# Question 361: Find top 10 discount-seeking customers.

# Question 362: Find customers with consistently negative profits.

# Question 363: Find customers buying across all categories.

# Question 364: Find customers buying across all sub-categories.

# Question 365: Find customers loyal to only one category.

# Question 366: Find customers loyal to only one sub-category.

# Question 367: Find customers retained across all 4 years.

# Question 368: Find customers active only in 1 year.

# Question 369: Find customers lost after first year.

# Question 370: Find new customers gained each year.

# Question 371: Find churn rate per year.

# Question 372: Find retention rate per year.

# Question 373: Calculate RFM (Recency, Frequency, Monetary) score.

# Question 374: Classify customers into Gold, Silver, Bronze segments.

# Question 375: Find correlation between frequency of orders and profit.

# Question 376: Find correlation between order size and discount usage.

# Question 377: Find sales per customer per year.

# Question 378: Find profit per customer per year.

# Question 379: Find customers with increasing sales trend.

# Question 380: Find customers with declining sales trend.

# Question 381: Identify top customers in Furniture category.

# Question 382: Identify top customers in Technology category.

# Question 383: Identify top customers in Office Supplies category.

# Question 384: Compare male vs female customers (if gender available).

# Question 385: Compare corporate vs consumer customers.

# Question 386: Compare sales per customer in East vs West.

# Question 387: Compare profit per customer in South vs Central.

# Question 388: Find average order frequency per customer.

# Question 389: Find customer with maximum purchase frequency.

# Question 390: Find customers who buy mostly in holiday season.

# Question 391: Find customers with lowest order frequency.

# Question 392: Find customers with highest order value volatility.

# Question 393: Find customers with stable order values.

# Question 394: Calculate revenue from top 20% customers (Pareto).

# Question 395: Calculate profit from top 20% customers (Pareto).

# Question 396: Apply K-means clustering on customers by sales & profit.

# Question 397: Apply hierarchical clustering on customers by RFM.

# Question 398: Product & Category Analysis (251–300)

# Question 399: Find product with maximum lifetime sales.

# Question 400: Find product with maximum lifetime profit.

# Product & Category Analysis (Questions 401-450)
# Question 401: Find product with maximum lifetime loss.

# Question 402: Find products with sales > average sales.

# Question 403: Find products with profit > average profit.

# Question 404: Find products with discount < average discount.

# Question 405: Identify seasonal products (selling only in certain months).

# Question 406: Identify evergreen products (selling all year).

# Question 407: Find fastest-growing product by sales.

# Question 408: Find fastest-declining product by sales.

# Question 409: Find products with consistently high discounts.

# Question 410: Find products with zero discount history.

# Question 411: Find products never sold in some regions.

# Question 412: Find products sold in all regions.

# Question 413: Find products sold in maximum number of states.

# Question 414: Find products sold in minimum number of states.

# Question 415: Rank products by order count.

# Question 416: Rank sub-categories by order count.

# Question 417: Rank categories by order count.

# Question 418: Rank products by repeat purchase frequency.

# Question 419: Find sub-category with maximum return on investment (ROI).

# Question 420: Find sub-category with minimum ROI.

# Question 421: Find sub-category with maximum volatility in profit.

# Question 422: Find sub-category with stable profit margin.

# Question 423: Compare profit margins across sub-categories.

# Question 424: Compare sales contribution of categories per year.

# Question 425: Compare profit contribution of categories per year.

# Question 426: Find correlation between price discount and sales per product.

# Question 427: Find correlation between price discount and profit per product.

# Question 428: Classify products into A, B, C (Pareto analysis by sales).

# Question 429: Classify products into A, B, C (Pareto analysis by profit).

# Question 430: Identify products with short lifecycle (sold only 1 year).

# Question 431: Identify products with long lifecycle (sold all years).

# Question 432: Find most expensive product sold.

# Question 433: Find least expensive product sold.

# Question 434: Find product with maximum order size (quantity).

# Question 435: Find product with minimum order size.

# Question 436: Find sub-category with highest dependency on discount.

# Question 437: Find sub-category with lowest dependency on discount.

# Question 438: Find most profitable product in each region.

# Question 439: Find least profitable product in each region.

# Question 440: Find most profitable sub-category in each region.

# Question 441: Find least profitable sub-category in each region.

# Question 442: Find category-subcategory pair with highest sales.

# Question 443: Find category-subcategory pair with lowest sales.

# Question 444: Rank sub-categories by average order size.

# Question 445: Rank products by average order size.

# Question 446: Compare product mix in each region.

# Question 447: Compare sub-category mix in each region.

# Question 448: Compare category mix in each region.

# Question 449: Advanced / Case-Based (351–500)

# Question 450: Time & Trend (351–400)

# Time & Trend Analysis (Questions 451-500)
# Question 451: Identify seasonality in monthly sales.

# Question 452: Identify seasonality in monthly profit.

# Question 453: Detect peak sales month per year.

# Question 454: Detect lowest sales month per year.

# Question 455: Compare growth trends across categories.

# Question 456: Compare growth trends across segments.

# Question 457: Compare sales in holiday seasons vs non-holiday.

# Question 458: Compare profit in holiday seasons vs non-holiday.

# Question 459: Compare Q1 vs Q4 sales trend.

# Question 460: Compare Q1 vs Q4 profit trend.

# Question 461: Find average lead time (order → ship) per region.

# Question 462: Find average lead time per ship mode.

# Question 463: Find fastest ship mode.

# Question 464: Find slowest ship mode.

# Question 465: Find late shipments (> expected days).

# Question 466: Find on-time shipments.

# Question 467: Compare profit between on-time vs late shipments.

# Question 468: Compare sales between on-time vs late shipments.

# Question 469: Detect trend of shipping delays by year.

# Question 470: Detect trend of shipping delays by region.

# Question 471: Find effect of shipping time on profit.

# Question 472: Find effect of shipping time on discount.

# Question 473: Compare weekend vs weekday sales.

# Question 474: Compare weekend vs weekday profit.

# Question 475: Compare pre-COVID vs post-COVID sales.

# Question 476: Compare pre-COVID vs post-COVID profit.

# Question 477: Find states with strongest rebound post-COVID.

# Question 478: Find states with largest dip post-COVID.

# Question 479: Find year with maximum order growth.

# Question 480: Find year with minimum order growth.

# Question 481: Compare sales volatility year-to-year.

# Question 482: Compare profit volatility year-to-year.

# Question 483: Identify states with most consistent sales.

# Question 484: Identify states with most inconsistent sales.

# Question 485: Detect cities with sudden sales spikes.

# Question 486: Detect cities with sudden sales drops.

# Question 487: Compare sales vs profit correlation over time.

# Question 488: Compare discount vs profit correlation over time.

# Question 489: Track customer retention per year.

# Question 490: Track segment share change per year.

# Question 491: Track category share change per year.

# Question 492: Track sub-category share change per year.

# Question 493: Find product lifecycles by first/last sale date.

# Question 494: Find customer lifecycles by first/last order date.

# Question 495: Forecast sales using moving average (12-month).

# Question 496: Forecast profit using moving average (12-month).

# Question 497: Forecast sales using linear regression.

# Question 498: Forecast profit using linear regression.

# Question 499: Forecast orders count using ARIMA.

# Question 500: Forecast discount usage using ARIMA.

# %%
import pandas as pd
data = pd.read_excel('/content/Sample - Superstore.xls')
df = pd.DataFrame(data)
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# Basic Level (Questions 1-150)
# Descriptive & Basic Queries (Questions 1-50)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# Question 1: Find total number of orders in the dataset.
# Total number of unique orders
total_orders = df['Order ID'].nunique()
print("Total number of orders:", total_orders)
# Out:
# Total number of orders: 5009

# %%
# Question 2: Find the earliest order date.

earliest_order_date = df['Order Date'].min()
print("Earliest order date:", earliest_order_date)
# Out:
# Earliest order date: 2014-01-03 00:00:00

# %%
# Question 3: Find the latest order date.

latest_order_date = df['Order Date'].max()
print("Latest order date:", latest_order_date)
# Out:
# Latest order date: 2017-12-30 00:00:00

# %%
# Question 4: Find the total number of unique customers.
unique_customers=df['Customer ID'].nunique()
print("Total number of unique customers:", unique_customers)
# Out:
# Total number of unique customers: 793

# %%
# Question 5: Find the total number of unique products sold.
unique_products = df['Product ID'].nunique()
print("Total number of unique products sold:", unique_products)
# Out:
# Total number of unique products sold: 1862

# %%
# Question 6: Find the total number of unique categories.
unique_categories = df['Category'].nunique()
print("Total number of unique categories:", unique_categories)
# Out:
# Total number of unique categories: 3

# %%
# Question 7: Find the total number of unique sub-categories.
unique_subcategories = df['Sub-Category'].nunique()
print("Total number of unique sub-categories:", unique_subcategories)
# Out:
# Total number of unique sub-categories: 17

# %%
# Question 8: Count number of orders in each region.
order_counts=df['Region'].value_counts()
print("Number of orders in each region:")
print(order_counts)
# Out:
# Number of orders in each region:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
# Question 9: Count number of orders by state.
order_counts_by_state = df['State'].value_counts()
print("Number of orders by state:")
print(order_counts_by_state)
# Out:
# Number of orders by state:
# State
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# ...

# %%
# Question 10: Count number of orders by city.
orders_per_city=df['City'].value_counts()
print("Number of orders by city:")
print(orders_per_city)
# Out:
# Number of orders by city:
# City
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
#                 ...
# Abilene            1
# Montebello         1
# Kissimmee          1
# Danbury            1
# Springdale         1
# Name: count, Length: 531, dtype: int64

# %%
# Question 11: Find the most common ship mode.
most_common_ship_mode = df['Ship Mode'].value_counts().idxmax()
print("Most common ship mode:", most_common_ship_mode)
# Out:
# Most common ship mode: Standard Class

# %%
# Question 12: Find the least common ship mode.
least_common_ship_mode = df['Ship Mode'].value_counts().idxmin()
print("Least common ship mode:", least_common_ship_mode)
# Out:
# Least common ship mode: Same Day

# %%
# Question 13: Count number of orders shipped with "Same Day" mode.
same_day_orders = df[df['Ship Mode'] == 'Same Day']
count_same_day_orders = len(same_day_orders)
print("Number of orders shipped with 'Same Day' mode:", count_same_day_orders)
# Out:
# Number of orders shipped with 'Same Day' mode: 543

# %%
# Question 14: Count number of orders shipped with "First Class".
first_class_orders = df[df['Ship Mode'] == 'First Class']
count_first_class_orders = len(first_class_orders)
print("Number of orders shipped with 'First Class' mode:", count_first_class_orders)
# Out:
# Number of orders shipped with 'First Class' mode: 1538

# %%
# Question 15: Count number of orders shipped with "Second Class".
second_class_orders = df[df['Ship Mode'] == 'Second Class']
count_second_class_orders = len(second_class_orders)
print("Number of orders shipped with 'Second Class' mode:", count_second_class_orders)
# Out:
# Number of orders shipped with 'Second Class' mode: 1945

# %%
# Question 16: Count number of orders shipped with "Standard Class".
standard_class_orders = df[df['Ship Mode'] == 'Standard Class']
count_standard_class_orders = len(standard_class_orders)
print("Number of orders shipped with 'Standard Class' mode:", count_standard_class_orders)
# Out:
# Number of orders shipped with 'Standard Class' mode: 5968

# %%
# Question 17: Find number of orders in each year.
# Ensure Order Date is in datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Extract year from Order Date
df['Year'] = df['Order Date'].dt.year

# Count number of unique orders per year
orders_per_year = df.groupby('Year')['Order ID'].nunique()

print(orders_per_year)
# Out:
# Year
# 2014     969
# 2015    1038
# 2016    1315
# 2017    1687
# Name: Order ID, dtype: int64

# %%
# Question 18: Find number of orders in each quarter.

# Extract the quarter from the order date
df['Quarter'] = df['Order Date'].dt.to_period('Q')

# Count the number of orders in each quarter
orders_per_quarter = df.groupby('Quarter')['Order ID'].nunique()

print(orders_per_quarter)
# Out:
# Quarter
# 2014Q1    131
# 2014Q2    201
# 2014Q3    267
# 2014Q4    370
# 2015Q1    144
# 2015Q2    214
# 2015Q3    274
# 2015Q4    406
# 2016Q1    179
# 2016Q2    294
# 2016Q3    378
# 2016Q4    464
# 2017Q1    240
# 2017Q2    367
# 2017Q3    448
# 2017Q4    632
# Freq: Q-DEC, Name: Order ID, dtype: int64

# %%
# Question 19: Find number of orders in each month.
# Extract the month from the order date
df['Month'] = df['Order Date'].dt.month

# Count the number of orders in each month
orders_per_month = df.groupby('Month')['Order ID'].nunique()

print(orders_per_month)
# Out:
# Month
# 1     178
# 2     162
# 3     354
# 4     343
# 5     369
# 6     364
# 7     338
# 8     341
# 9     688
# 10    417
# 11    753
# 12    702
# Name: Order ID, dtype: int64

# %%
# Question 20: Find number of orders in each weekday.
# Extract the weekday from the order date
df['Weekday'] = df['Order Date'].dt.day_name()

# Count the number of orders in each weekday
orders_per_weekday = df.groupby('Weekday')['Order ID'].nunique()
print(orders_per_weekday)
# Out:
# Weekday
# Friday       916
# Monday       920
# Saturday     837
# Sunday       850
# Thursday     746
# Tuesday      558
# Wednesday    182
# Name: Order ID, dtype: int64

# %%
# Question 21: Count orders with discount applied.
orders_with_discount = df[df['Discount'] > 0]
count_orders_with_discount = len(orders_with_discount)
print("Number of orders with discount applied:", count_orders_with_discount)
# Out:
# Number of orders with discount applied: 5196

# %%
# Question 22: Count orders without discount.
orders_without_discount = df[df['Discount'] < 0]
count_orders_without_discount = len(orders_without_discount)
print("Number of orders without discount:", count_orders_without_discount)
# Out:
# Number of orders without discount: 0

# %%
# Question 23: Count orders where discount = 0.
orders_with_zero_discount = df[df['Discount'] == 0]
count_orders_with_zero_discount = len(orders_with_zero_discount)
print("Number of orders with zero discount:", count_orders_with_zero_discount)
# Out:
# Number of orders with zero discount: 4798

# %%
# Question 24: Count orders where discount > 0.2.
orders_with_high_discount = df[df['Discount'] > 0.2]
count_orders_with_high_discount = len(orders_with_high_discount)
print("Number of orders with high discount:", count_orders_with_high_discount)
# Out:
# Number of orders with high discount: 1393

# %%
# Question 25: Count orders where discount = 0.5.
orders_with_medium_discount = df[df['Discount'] == 0.5]
count_orders_with_medium_discount = len(orders_with_medium_discount)
print("Number of orders with medium discount:", count_orders_with_medium_discount)
# Out:
# Number of orders with medium discount: 66

# %%
# Question 26: Find maximum discount given.
max_discount = df['Discount'].max()
print("Maximum discount given:", max_discount)
# Out:
# Maximum discount given: 0.8

# %%
# Question 27: Find minimum discount given.
min_discount = df['Discount'].min()
print("Minimum discount given:", min_discount)
# Out:
# Minimum discount given: 0.0

# %%
# Question 28: Count orders where profit < 0.
orders_with_negative_profit = df[df['Profit'] < 0]
count_orders_with_negative_profit = len(orders_with_negative_profit)
print("Number of orders with negative profit:", count_orders_with_negative_profit)
# Out:
# Number of orders with negative profit: 1871

# %%
# Question 29: Count orders where profit = 0.
orders_with_zero_profit = df[df['Profit'] == 0]
count_orders_with_zero_profit = len(orders_with_zero_profit)
print("Number of orders with zero profit:", count_orders_with_zero_profit)
# Out:
# Number of orders with zero profit: 65

# %%
# Question 30: Count orders where profit > 100.
orders_with_high_profit = df[df['Profit'] > 100]
count_orders_with_high_profit = len(orders_with_high_profit)
print("Number of orders with high profit:", count_orders_with_high_profit)
# Out:
# Number of orders with high profit: 890

# %%
# Question 31: Count orders where sales > 1000
orders_with_high_sales = df[df['Sales'] > 1000]
count_orders_with_high_sales = len(orders_with_high_sales)
print("Number of orders with high sales:", count_orders_with_high_sales)
# Out:
# Number of orders with high sales: 468

# %%
# Question 32: Find total quantity sold.
total_quantity_sold = df['Quantity'].sum()
print("Total quantity sold:", total_quantity_sold)
# Out:
# Total quantity sold: 37873

# %%
#  Question 33: Find average quantity per order.
average_quantity_per_order = df.groupby('Order ID')['Quantity'].sum().mean()
print("Average quantity per order:", average_quantity_per_order)
# Out:
# Average quantity per order: 7.560990217608305

# %%
# Question 34: Find average sales per order.
average_sales_per_order = df.groupby('Order ID')['Sales'].sum().mean()
print("Average sales per order:", average_sales_per_order)
# Out:
# Average sales per order: 458.61466566180883

# %%
# Question 35: Find average profit per order.
average_profit_per_order = df.groupby('Order ID')['Profit'].sum().mean()
print("Average profit per order:", average_profit_per_order)
# Out:
# Average profit per order: 57.17648666400478

# %%
# Question 36: Find maximum sales in a single order.
max_sales_per_order = df.groupby('Order ID')['Sales'].sum().max()
print("Maximum sales in a single order:", max_sales_per_order)
# Out:
# Maximum sales in a single order: 23661.228

# %%
# Question 37: Find minimum sales in a single order.
min_sales_per_order = df.groupby('Order ID')['Sales'].sum().min()
print("Minimum sales in a single order:", min_sales_per_order)
# Out:
# Minimum sales in a single order: 0.5559999999999998

# %%
# Question 38: Find maximum profit in a single order.
max_profit_per_order = df.groupby('Order ID')['Profit'].sum().max()
print("Maximum profit in a single order:", max_profit_per_order)
# Out:
# Maximum profit in a single order: 8762.389099999999

# %%
# Question 39: Find minimum profit in a single order.
min_profit_per_order = df.groupby('Order ID')['Profit'].sum().min()
print("Minimum profit in a single order:", min_profit_per_order)
# Out:
# Minimum profit in a single order: -6892.3748000000005

# %%
# Question 40: Find number of orders per customer.
orders_per_customer = df.groupby('Customer ID')['Order ID'].nunique()
print("Number of orders per customer:")
print(orders_per_customer)
# Out:
# Number of orders per customer:
# Customer ID
# AA-10315     5
# AA-10375     9
# AA-10480     4
# AA-10645     6
# AB-10015     3
#             ..
# XP-21865    11
# YC-21895     5
# YS-21880     8
# ZC-21910    13
# ZD-21925     5
# Name: Order ID, Length: 793, dtype: int64

# %%
# Question 41: Find customers who placed only 1 order.
customers_with_one_order = orders_per_customer[orders_per_customer == 1]
print("Customers who placed only 1 order:")
print(customers_with_one_order)
# Out:
# Customers who placed only 1 order:
# Customer ID
# AO-10810    1
# AR-10570    1
# CJ-11875    1
# JC-15385    1
# JR-15700    1
# LD-16855    1
# MG-18205    1
# PH-18790    1
# RE-19405    1
# RM-19750    1
# SM-20905    1
# TC-21145    1
# Name: Order ID, dtype: int64

# %%
# Question 42: Find customers who placed more than 10 orders.
customers_with_more_than_10_orders = orders_per_customer[orders_per_customer > 10]
print("Customers who placed more than 10 orders:")
print(customers_with_more_than_10_orders)
# Out:
# Customers who placed more than 10 orders:
# Customer ID
# AH-10690    12
# BD-11320    12
# BF-11170    11
# BM-11650    11
# BP-11095    12
# CC-12220    12
# CK-12205    13
# CK-12595    11
# CL-12565    12
# CS-11950    11
# CS-12250    12
# CS-12355    11
# DK-12835    12
# Dp-13240    11
# EA-14035    13
# EH-13765    12
# EP-13915    17
# GA-14725    11
# GB-14530    11
# GT-14710    11
# HG-14965    12
# JD-15895    11
# JE-15745    13
# JF-15490    11
# JG-15160    11
# JL-15835    11
# KB-16585    12
# KD-16495    12
# KL-16645    12
# LA-16780    11
# LC-16885    12
# MA-17560    11
# MM-17920    11
# MY-18295    11
# NS-18640    13
# PG-18820    13
# PK-19075    12
# PO-18850    11
# RB-19465    12
# RP-19390    12
# SC-20725    11
# SE-20110    11
# SH-19975    13
# SJ-20125    12
# SM-20950    12
# SZ-20035    11
# WB-21850    11
# XP-21865    11
# ZC-21910    13
# Name: Order ID, dtype: int64

# %%
# Question 43: Find total number of states represented.
total_states = df['State'].nunique()
print("Total number of states represented:", total_states)
# Out:
# Total number of states represented: 49

# %%
# Question 44: Find total number of cities represented.
total_cities = df['City'].nunique()
print("Total number of cities represented:", total_cities)
# Out:
# Total number of cities represented: 531

# %%
# Question 45: Find number of orders placed from California.
orders_from_california = df[df['State'] == 'California']
count_orders_from_california = len(orders_from_california)
print("Number of orders placed from California:", count_orders_from_california)
# Out:
# Number of orders placed from California: 2001

# %%
# Question 46: Find number of orders placed from New York.
orders_from_new_york = df[df['State'] == 'New York']
count_orders_from_new_york = len(orders_from_new_york)
print("Number of orders placed from New York:", count_orders_from_new_york)
# Out:
# Number of orders placed from New York: 1128

# %%
# Question 47: Find number of orders placed from Texas.
orders_from_texas = df[df['State'] == 'Texas']
count_orders_from_texas = len(orders_from_texas)
print("Number of orders placed from Texas:", count_orders_from_texas)
# Out:
# Number of orders placed from Texas: 985

# %%
# Question 48: Find number of orders placed from Florida.
orders_from_florida = df[df['State'] == 'Florida']
count_orders_from_florida = len(orders_from_florida)
print("Number of orders placed from Florida:", count_orders_from_florida)
# Out:
# Number of orders placed from Florida: 383

# %%
# Question 49: Find number of orders shipped after 5 days of order.
# Ensure both columns are datetime
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# Calculate shipping duration in days
df['Ship_Days'] = (df['Ship Date'] - df['Order Date']).dt.days

# Count orders shipped after 5 days
orders_after_5_days = df[df['Ship_Days'] > 5]['Order ID'].count()

print("Number of orders shipped after 5 days:", orders_after_5_days)
# Out:
# Number of orders shipped after 5 days: 1824

# %%
# Question 50: Find average shipping time in days.
average_shipping_time = df['Ship_Days'].mean()
print("Average shipping time in days:", average_shipping_time)
# Out:
# Average shipping time in days: 3.958174904942966

# %%
# Sales & Profit Analysis (Questions 51-100)

# %%
# Question 51: Find total sales.
total_sales = df['Sales'].sum()
print("Total sales:", total_sales)
# Out:
# Total sales: 2297200.8603000003

# %%
# Question 52: Find total profit.
total_profit = df['Profit'].sum()
print("Total profit:", total_profit)
# Out:
# Total profit: 286397.0216999999

# %%
# Question 53: Find average sales per order.
average_sales=df.groupby('Order ID')['Sales'].sum().mean()
print("Average sales per order:", average_sales)
# Out:
# Average sales per order: 458.61466566180883

# %%
# Question 54: Find average profit per order.
average_profit=df.groupby('Order ID')['Profit'].sum().mean()
print("Average profit per order:", average_profit)
# Out:
# Average profit per order: 57.17648666400478

# %%
# Question 55: Find sales by category.
sales_by_category = df.groupby('Category')['Sales'].sum()
print("Sales by category:")
print(sales_by_category)
# Out:
# Sales by category:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
# Question 56: Find profit by category.
profit_by_category = df.groupby('Category')['Profit'].sum()
print("Profit by category:")
print(profit_by_category)
# Out:
# Profit by category:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
# Question 57: Find sales by sub-category.
sales_by_sub_category = df.groupby('Sub-Category')['Sales'].sum()
print("Sales by sub-category:")
print(sales_by_sub_category)
# Out:
# Sales by sub-category:
# Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27118.7920
# Binders        203412.7330
# Bookcases      114879.9963
# Chairs         328449.1030
# Copiers        149528.0300
# Envelopes       16476.4020
# Fasteners        3024.2800
# Furnishings     91705.1640
# Labels          12486.3120
# Machines       189238.6310
# Paper           78479.2060
# Phones         330007.0540
# Storage        223843.6080
# Supplies        46673.5380
# Tables         206965.5320
# Name: Sales, dtype: float64

# %%
# Question 58: Find profit by sub-category.
profit_by_sub_category = df.groupby('Sub-Category')['Profit'].sum()
print("Profit by sub-category:")
print(profit_by_sub_category)
# Out:
# Profit by sub-category:
# Sub-Category
# Accessories    41936.6357
# Appliances     18138.0054
# Art             6527.7870
# Binders        30221.7633
# Bookcases      -3472.5560
# Chairs         26590.1663
# Copiers        55617.8249
# Envelopes       6964.1767
# Fasteners        949.5182
# Furnishings    13059.1436
# Labels          5546.2540
# Machines        3384.7569
# Paper          34053.5693
# Phones         44515.7306
# Storage        21278.8264
# Supplies       -1189.0995
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
# Question 59: Find highest sales category.
highest_sales_category = df.groupby('Category')['Sales'].sum().idxmax()
print("Highest sales category:", highest_sales_category)
# Out:
# Highest sales category: Technology

# %%
# Question 60: Find highest profit category.
highest_profit_category = df.groupby('Category')['Profit'].sum().idxmax()
print("Highest profit category:", highest_profit_category)
# Out:
# Highest profit category: Technology

# %%
# Question 61: Find lowest profit category.
lowest_profit_category = df.groupby('Category')['Profit'].sum().idxmin()
print("Lowest profit category:", lowest_profit_category)
# Out:
# Lowest profit category: Furniture

# %%
# Question 62: Find lowest sales sub-category.
lowest_sales_sub_category = df.groupby('Sub-Category')['Sales'].sum().idxmin()
print("Lowest sales sub-category:", lowest_sales_sub_category)
# Out:
# Lowest sales sub-category: Fasteners

# %%
# Question 63: Find highest profit sub-category.
highest_profit_sub_category = df.groupby('Sub-Category')['Profit'].sum().idxmax()
print("Highest profit sub-category:", highest_profit_sub_category)
# Out:
# Highest profit sub-category: Copiers

# %%
# Question 64: Find lowest profit sub-category.
lowest_profit_sub_category = df.groupby('Sub-Category')['Profit'].sum().idxmin()
print("Lowest profit sub-category:", lowest_profit_sub_category)
# Out:
# Lowest profit sub-category: Tables

# %%
# Question 65: Find top 10 profitable products.
top_10_profitable_products = df.groupby('Product Name')['Profit'].sum().nlargest(10)
print("Top 10 profitable products:")
print(top_10_profitable_products)
# Out:
# Top 10 profitable products:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          25199.9280
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind     7753.0390
# Hewlett Packard LaserJet 3310 Copier                                            6983.8836
# Canon PC1060 Personal Laser Copier                                              4570.9347
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                       4094.9766
# Ativa V4110MDD Micro-Cut Shredder                                               3772.9461
# 3D Systems Cube Printer, 2nd Generation, Magenta                                3717.9714
# Plantronics Savi W720 Multi-Device Wireless Headset System                      3696.2820
# Ibico EPK-21 Electric Binding System                                            3345.2823
# Zebra ZM400 Thermal Label Printer                                               3343.5360
# Name: Profit, dtype: float64

# %%
# Question 66: Find top 10 least profitable products.
top_10_least_profitable_products = df.groupby('Product Name')['Profit'].sum().nsmallest(10)
print("Top 10 least profitable products:")
print(top_10_least_profitable_products)
# Out:
# Top 10 least profitable products:
# Product Name
# Cubify CubeX 3D Printer Double Head Print                           -8879.9704
# Lexmark MX611dhe Monochrome Laser Printer                           -4589.9730
# Cubify CubeX 3D Printer Triple Head Print                           -3839.9904
# Chromcraft Bull-Nose Wood Oval Conference Tables & Bases            -2876.1156
# Bush Advantage Collection Racetrack Conference Table                -1934.3976
# GBC DocuBind P400 Electric Binding System                           -1878.1662
# Cisco TelePresence System EX90 Videoconferencing Unit               -1811.0784
# Martin Yale Chadless Opener Electric Letter Opener                  -1299.1836
# Balt Solid Wood Round Tables                                        -1201.0581
# BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables   -1148.4375
# Name: Profit, dtype: float64

# %%
# Question 67: Find top 10 best-selling products by sales.
top_10_best_selling_products = df.groupby('Product Name')['Sales'].sum().nlargest(10)
print("Top 10 best-selling products by sales:")
print(top_10_best_selling_products)
# Out:
# Top 10 best-selling products by sales:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
# Question 68: Find top 10 best-selling products by quantity.
top_10_best_selling_products_quantity = df.groupby('Product Name')['Quantity'].sum().nlargest(10)
print("Top 10 best-selling products by quantity:")
print(top_10_best_selling_products_quantity)
# Out:
# Top 10 best-selling products by quantity:
# Product Name
# Staples                                                       215
# Staple envelope                                               170
# Easy-staple paper                                             150
# Staples in misc. colors                                        86
# KI Adjustable-Height Table                                     74
# Avery Non-Stick Binders                                        71
# Storex Dura Pro Binders                                        71
# GBC Premium Transparent Covers with Diagonal Lined Pattern     67
# Situations Contoured Folding Chairs, 4/Set                     64
# Staple-based wall hangings                                     62
# Name: Quantity, dtype: int64

# %%
# Question 69: Find bottom 10 products by sales.
bottom_10_products_by_sales = df.groupby('Product Name')['Sales'].sum().nsmallest(10)
print("Bottom 10 products by sales:")
print(bottom_10_products_by_sales)
# Out:
# Bottom 10 products by sales:
# Product Name
# Eureka Disposable Bags for Sanitaire Vibra Groomer I Upright Vac    1.624
# Avery 5                                                             5.760
# Xerox 20                                                            6.480
# Grip Seal Envelopes                                                 7.072
# Avery Hi-Liter Pen Style Six-Color Fluorescent Set                  7.700
# Avery Hi-Liter Comfort Grip Fluorescent Highlighter, Yellow Ink     7.800
# Xerox 1989                                                          7.968
# 4009 Highlighters                                                   8.040
# Stockwell Gold Paper Clips                                          8.096
# Newell 308                                                          8.400
# Name: Sales, dtype: float64

# %%
# Question 70: Find bottom 10 products by profit.
bottom_10_products_by_profit = df.groupby('Product Name')['Profit'].sum().nsmallest(10)
print("Bottom 10 products by profit:")
print(bottom_10_products_by_profit)
# Out:
# Bottom 10 products by profit:
# Product Name
# Cubify CubeX 3D Printer Double Head Print                           -8879.9704
# Lexmark MX611dhe Monochrome Laser Printer                           -4589.9730
# Cubify CubeX 3D Printer Triple Head Print                           -3839.9904
# Chromcraft Bull-Nose Wood Oval Conference Tables & Bases            -2876.1156
# Bush Advantage Collection Racetrack Conference Table                -1934.3976
# GBC DocuBind P400 Electric Binding System                           -1878.1662
# Cisco TelePresence System EX90 Videoconferencing Unit               -1811.0784
# Martin Yale Chadless Opener Electric Letter Opener                  -1299.1836
# Balt Solid Wood Round Tables                                        -1201.0581
# BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables   -1148.4375
# Name: Profit, dtype: float64

# %%
# Question 71: Find total sales by year.
total_sales_by_year = df.groupby(df['Order Date'].dt.year)['Sales'].sum()
print("Total sales by year:")
print(total_sales_by_year)
# Out:
# Total sales by year:
# Order Date
# 2014    484247.4981
# 2015    470532.5090
# 2016    609205.5980
# 2017    733215.2552
# Name: Sales, dtype: float64

# %%
# Question 72: Find total profit by year.
total_profit_by_year = df.groupby(df['Order Date'].dt.year)['Profit'].sum()
print("Total profit by year:")
print(total_profit_by_year)
# Out:
# Total profit by year:
# Order Date
# 2014    49543.9741
# 2015    61618.6037
# 2016    81795.1743
# 2017    93439.2696
# Name: Profit, dtype: float64

# %%
# Question 73: Find sales growth year by year.
sales_growth = total_sales_by_year.pct_change() * 100
print("Sales growth year by year:")
print(sales_growth)
# Out:
# Sales growth year by year:
# Order Date
# 2014          NaN
# 2015    -2.832227
# 2016    29.471521
# 2017    20.355962
# Name: Sales, dtype: float64

# %%
# Question 74: Find profit growth year by year.
profit_growth = total_profit_by_year.pct_change() * 100
print("Profit growth year by year:")
print(profit_growth)

# %%
# Question 75: Find sales by quarter.
sales_by_quarter = df.groupby(df['Order Date'].dt.to_period('Q'))['Sales'].sum()
print("Sales by quarter:")
print(sales_by_quarter)
# Out:
# Sales by quarter:
# Order Date
# 2014Q1     74447.7960
# 2014Q2     86538.7596
# 2014Q3    143633.2123
# 2014Q4    179627.7302
# 2015Q1     68851.7386
# 2015Q2     89124.1870
# 2015Q3    130259.5752
# 2015Q4    182297.0082
# 2016Q1     93237.1810
# 2016Q2    136082.3010
# 2016Q3    143787.3622
# 2016Q4    236098.7538
# 2017Q1    123144.8602
# 2017Q2    133764.3720
# 2017Q3    196251.9560
# 2017Q4    280054.0670
# Freq: Q-DEC, Name: Sales, dtype: float64

# %%
# Question 76: Find profit by quarter.
profit_by_quarter = df.groupby(df['Order Date'].dt.to_period('Q'))['Profit'].sum()
print("Profit by quarter:")
print(profit_by_quarter)
# Out:
# Profit by quarter:
# Order Date
# 2014Q1     3811.2290
# 2014Q2    11204.0692
# 2014Q3    12804.7218
# 2014Q4    21723.9541
# 2015Q1     9264.9416
# 2015Q2    12190.9224
# 2015Q3    16853.6194
# 2015Q4    23309.1203
# 2016Q1    11441.3708
# 2016Q2    16390.3394
# 2016Q3    15823.6048
# 2016Q4    38139.8593
# 2017Q1    23506.2026
# 2017Q2    15499.2085
# 2017Q3    26985.1325
# 2017Q4    27448.7260
# Freq: Q-DEC, Name: Profit, dtype: float64

# %%
# Question 77: Find sales by month.
sales_by_month = df.groupby(df['Order Date'].dt.month)['Sales'].sum()
print("Sales by month:")
print(sales_by_month)
# Out:
# Sales by month:
# Order Date
# 1      94924.8356
# 2      59751.2514
# 3     205005.4888
# 4     137762.1286
# 5     155028.8117
# 6     152718.6793
# 7     147238.0970
# 8     159044.0630
# 9     307649.9457
# 10    200322.9847
# 11    352461.0710
# 12    325293.5035
# Name: Sales, dtype: float64

# %%
# Question 78: Find profit by month.
profit_by_month = df.groupby(df['Order Date'].dt.month)['Profit'].sum()
print("Profit by month:")
print(profit_by_month)
# Out:
# Profit by month:
# Order Date
# 1      9134.4461
# 2     10294.6107
# 3     28594.6872
# 4     11587.4363
# 5     22411.3078
# 6     21285.7954
# 7     13832.6648
# 8     21776.9384
# 9     36857.4753
# 10    31784.0413
# 11    35468.4265
# 12    43369.1919
# Name: Profit, dtype: float64

# %%
# Question 79: Find month with highest sales.
month_with_highest_sales = df.groupby(df['Order Date'].dt.month)['Sales'].sum().idxmax()
print("Month with highest sales:", month_with_highest_sales)
# Out:
# Month with highest sales: 11

# %%
# Question 80: Find month with highest profit.
month_with_highest_profit = df.groupby(df['Order Date'].dt.month)['Profit'].sum().idxmax()
print("Month with highest profit:", month_with_highest_profit)
# Out:
# Month with highest profit: 12

# %%
# Question 81: Find month with lowest sales.
month_with_lowest_sales = df.groupby(df['Order Date'].dt.month)['Sales'].sum().idxmin()
print("Month with lowest sales:", month_with_lowest_sales)
# Out:
# Month with lowest sales: 2

# %%
#  Question 82: Find month with lowest profit.
month_with_lowest_profit = df.groupby(df['Order Date'].dt.month)['Profit'].sum().idxmin()
print("Month with lowest profit:", month_with_lowest_profit)
# Out:
# Month with lowest profit: 1

# %%
# Question 83: Find total sales by weekday.
sales_by_weekday = df.groupby(df['Order Date'].dt.day_name())['Sales'].sum()
print("Total sales by weekday:")
print(sales_by_weekday)
# Out:
# Total sales by weekday:
# Order Date
# Friday       427692.2593
# Monday       428937.8157
# Saturday     357984.6830
# Sunday       385353.8464
# Thursday     321965.7785
# Tuesday      287209.5022
# Wednesday     88056.9752
# Name: Sales, dtype: float64

# %%
# Question 84: Find total profit by weekday.
profit_by_weekday = df.groupby(df['Order Date'].dt.day_name())['Profit'].sum()
print("Total profit by weekday:")
print(profit_by_weekday)
# Out:
# Total profit by weekday:
# Order Date
# Friday       46520.8242
# Monday       51511.1146
# Saturday     41277.6202
# Sunday       57129.5120
# Thursday     39683.7512
# Tuesday      35570.3288
# Wednesday    14703.8707
# Name: Profit, dtype: float64

# %%
# Question 85: Find weekday with highest sales.
weekday_with_highest_sales = df.groupby(df['Order Date'].dt.day_name())['Sales'].sum().idxmax()
print("Weekday with highest sales:", weekday_with_highest_sales)
# Out:
# Weekday with highest sales: Monday

# %%
# Question 86: Find weekday with lowest sales.
weekday_with_lowest_sales = df.groupby(df['Order Date'].dt.day_name())['Sales'].sum().idxmin()
print("Weekday with lowest sales:", weekday_with_lowest_sales)
# Out:
# Weekday with lowest sales: Wednesday

# %%
# Question 87: Find weekday with highest profit.
weekday_with_highest_profit = df.groupby(df['Order Date'].dt.day_name())['Profit'].sum().idxmax()
print("Weekday with highest profit:", weekday_with_highest_profit)
# Out:
# Weekday with highest profit: Sunday

# %%
# Question 88: Find weekday with lowest profit.
weekday_with_lowest_profit = df.groupby(df['Order Date'].dt.day_name())['Profit'].sum().idxmin()
print("Weekday with lowest profit:", weekday_with_lowest_profit)
# Out:
# Weekday with lowest profit: Wednesday

# %%
# Question 89: Find state with highest sales.
state_with_highest_sales = df.groupby('State')['Sales'].sum().idxmax()
print("State with highest sales:", state_with_highest_sales)
# Out:
# State with highest sales: California

# %%
# Question 90: Find state with highest profit.
state_with_highest_profit = df.groupby('State')['Profit'].sum().idxmax()
print("State with highest profit:", state_with_highest_profit)
# Out:
# State with highest profit: California

# %%
# Question 91: Find state with lowest sales.
state_with_lowest_sales = df.groupby('State')['Sales'].sum().idxmin()
print("State with lowest sales:", state_with_lowest_sales)
# Out:
# State with lowest sales: North Dakota

# %%
# Question 92: Find state with lowest profit.
state_with_lowest_profit = df.groupby('State')['Profit'].sum().idxmin()
print("State with lowest profit:", state_with_lowest_profit)
# Out:
# State with lowest profit: Texas

# %%
# Question 93: Find region with highest sales.
region_with_highest_sales = df.groupby('Region')['Sales'].sum().idxmax()
print("Region with highest sales:", region_with_highest_sales)
# Out:
# Region with highest sales: West

# %%
# Question 94: Find region with highest profit.
region_with_highest_profit = df.groupby('Region')['Profit'].sum().idxmax()
print("Region with highest profit:", region_with_highest_profit)
# Out:
# Region with highest profit: West

# %%
# Question 95: Find region with lowest sales.
region_with_lowest_sales = df.groupby('Region')['Sales'].sum().idxmin()
print("Region with lowest sales:", region_with_lowest_sales)
# Out:
# Region with lowest sales: South

# %%
# Question 96: Find region with lowest profit.
region_with_lowest_profit = df.groupby('Region')['Profit'].sum().idxmin()
print("Region with lowest profit:", region_with_lowest_profit)
# Out:
# Region with lowest profit: Central

# %%
# Question 97: Find average discount overall.
average_discount = df['Discount'].mean()
print("Average discount overall:", average_discount)
# Out:
# Average discount overall: 0.15620272163297977

# %%
# Question 98: Find average discount in each category.
average_discount_by_category = df.groupby('Category')['Discount'].mean()
print("Average discount in each category:")
print(average_discount_by_category)
# Out:
# Average discount in each category:
# Category
# Furniture          0.173923
# Office Supplies    0.157285
# Technology         0.132323
# Name: Discount, dtype: float64

# %%
# Question 99: Find average discount in each sub-category.
average_discount_by_sub_category = df.groupby('Sub-Category')['Discount'].mean()
print("Average discount in each sub-category:")
print(average_discount_by_sub_category)
# Out:
# Average discount in each sub-category:
# Sub-Category
# Accessories    0.078452
# Appliances     0.166524
# Art            0.074874
# Binders        0.372292
# Bookcases      0.211140
# Chairs         0.170178
# Copiers        0.161765
# Envelopes      0.080315
# Fasteners      0.082028
# Furnishings    0.138349
# Labels         0.068681
# Machines       0.306087
# Paper          0.074891
# Phones         0.154556
# Storage        0.074704
# Supplies       0.076842
# Tables         0.261285
# Name: Discount, dtype: float64

# %%
# Question 100: Compare total sales vs profit across regions.
total_sales_by_region = df.groupby('Region')['Sales'].sum()
total_profit_by_region = df.groupby('Region')['Profit'].sum()
print("Total sales by region:")
print(total_sales_by_region)
print("Total profit by region:")
print(total_profit_by_region)
# Out:
# Total sales by region:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64
# Total profit by region:
# Region
# Central     39706.3625
# East        91522.7800
# South       46749.4303
# West       108418.4489
# Name: Profit, dtype: float64
